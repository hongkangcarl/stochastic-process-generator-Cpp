# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ou = np.genfromtxt('./output.csv', delimiter=',')
t = ou[0]
Us = ou[1:]

for U in Us:
    plt.plot(t, U)
plt.title("Brownian motion")
plt.xlabel(r"$t$")
plt.ylabel(r"$W_t$")
# Out:
# Text(0, 0.5, '$W_t$')
